# %% [markdown]
# Numpy, Pandas, Matplotlib, and Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the file
df_train = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')

# %%
#display top n rows n=10
df_train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
#display ten rows randomly
df_train[400:410]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 400  401         120       RL         38.0    14963   Pave   NaN      IR2
# 401  402          20       RL         65.0     8767   Pave   NaN      IR1
# 402  403          30       RL         60.0    10200   Pave   NaN      Reg
# 403  404          60       RL         93.0    12090   Pave   NaN      Reg
# 404  405          60       RL          NaN    10364   Pave   NaN      IR1
# 405  406          20       RL          NaN     9991   Pave   NaN      IR1
# 406  407          50       RL         51.0    10480   Pave   NaN      Reg
# 407  408          70       RL         63.0    15576   Pave   NaN      Reg
# 408  409          60       RL        109.0    14154   Pave   NaN      Reg
# 409  410          60       FV         85.0    10800   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 400         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
#display headers
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#find unique neighbourhood values
unique_neighbour = df_train['Neighborhood'].unique()
print(unique_neighbour)
# Out:
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']

# %%
unique_neighbour[0:25]
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
#find the median prices for all neighbourhood
neighbour_median = []
for item in unique_neighbour:
    neighbour_prices = df_train.loc[df_train['Neighborhood'] == item,'SalePrice']
    neighbour_median.append(np.median(neighbour_prices))
neighbour_median
# Out:
# [197200.0,
#  218000.0,
#  200624.0,
#  301500.0,
#  153500.0,
#  225500.0,
#  182900.0,
#  119000.0,
#  124300.0,
#  135000.0,
#  315000.0,
#  140000.0,
#  179900.0,
#  103000.0,
#  88000.0,
#  121750.0,
#  228475.0,
#  181000.0,
#  278000.0,
#  200250.0,
#  146000.0,
#  191000.0,
#  106000.0,
#  139500.0,
#  137500.0]

# %%
#plot bar chart
plt.figure(figsize=(12,7))
plt.bar(unique_neighbour,neighbour_median,color=['blue'])
plt.xlabel('Neighborhood')
ax = plt.xticks(rotation=45)
plt.ylabel('Median price')
plt.title("Median house price of each neighborhood")
plt.show()

# %%
#Relationship with several numerical variable

#scatter plot Above grade (ground) living area square feet (grlivarea)/saleprice
var = 'GrLivArea'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,900000));

# %%
#Relationship with categorical feature

#box plot Rates the overall material and finish of the house (OverallQual)/saleprice
var = 'OverallQual'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=900000);
